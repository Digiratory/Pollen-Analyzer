# %%
# !pip install ray[tune]
# !pip install grpcio
# !pip install grpcio-tools
# !pip install timm

# %%
# !python3 -c "import lightning" || pip install lightning==2.2.4
# !python3 -c "import torchsummary" || pip install torchsummary

# %%
import os
import torch
import tempfile
import timm
import numpy as np
from typing import Tuple
import itertools
import matplotlib.pyplot as plt
import lightning.pytorch as pl
from lightning.pytorch.callbacks import ModelCheckpoint
from torchvision.transforms.v2 import functional as TVF
import torch.nn.functional as F
import lightning as L
from torch import nn, Tensor
from torch.utils.data import Dataset
from filelock import FileLock
from torchmetrics import Accuracy
from torch.utils.data import DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision import transforms
from torchvision import models
from torchvision.transforms import v2
from ray import tune
from ray.tune import ExperimentAnalysis
from ray.tune import Tuner
from ray.tune.schedulers import ASHAScheduler
from ray.tune import ProgressReporter
from ray.tune.progress_reporter import JupyterNotebookReporter
from ray.train import RunConfig, CheckpointConfig, ScalingConfig
from ray.train.lightning import (
    RayDDPStrategy,
    RayFSDPStrategy,
    RayLightningEnvironment,
    RayTrainReportCallback,
    prepare_trainer,
)
from sklearn.model_selection import train_test_split
import random
from PIL import Image, ImageOps
from tqdm.notebook import tqdm
from glob import glob

# %%
OBJECTS_ROOT = r"/home/shared/datasets/pollen_dataset_2024_05_08_objects_clear/pollen_dataset_2024_05_08_objects"

# %%
def pad2size(image, size=(224, 224)):
    return ImageOps.fit(image, size)

class PollenTripletDataset(Dataset):
    def __init__(self, img_dir, classes, 
                 static_transform=None, 
                 random_transform=None,
                 inflation_rate=1):
        self.known_classes = classes
        self.known_classes.sort()
        self.transform = random_transform
        self._all_samples = []
        self._class_to_number = {c: torch.tensor(i, dtype=torch.int8) for i,c in enumerate(self.known_classes)}

        total_samples = 0
        for c in tqdm(self.known_classes):
            images = glob(os.path.join(img_dir, c, "*.png"))
            print(f"{len(images)} samples in the class {c}")
            
            for idx, img_path in enumerate(tqdm(images)):
                img = Image.open(img_path)
                if static_transform is not None:
                    img = static_transform(img)
                self._all_samples.append((c, img))
                total_samples += 1
        
        print(f"Total samples: {total_samples}")

    def __len__(self):
        return len(self._all_samples)

    def __getitem__(self, idx):
        name, img = self._all_samples[idx]
        label = self._class_to_number[name]
        return img, label, name

known_classes = os.listdir(OBJECTS_ROOT)#['Alnus', 'Betula', 'Acer', 'Pinus', 'Salix', 'Tilia', 'Quercus']

print(f"All known classes: {known_classes}")
train_classes, val_classes = train_test_split(known_classes, test_size=0.2, random_state=42)
train_classes, test_classes = train_test_split(train_classes, test_size=0.2, random_state=42)

print(f"Train classes: {train_classes}")
print(f"Validation classes: {val_classes}")
print(f"Test classes: {test_classes}")

input_size=(224, 224)

static_transforms = v2.Compose([
    v2.Lambda(pad2size),
    v2.PILToTensor(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])


print("\nLoad Train Dataset")
dataset_train = PollenTripletDataset(OBJECTS_ROOT, train_classes, static_transform=static_transforms, inflation_rate=100)
print("\nLoad Validation Dataset")
dataset_val = PollenTripletDataset(OBJECTS_ROOT, val_classes, static_transform=static_transforms, inflation_rate=100)
print("\nLoad Test Dataset")
dataset_test = PollenTripletDataset(OBJECTS_ROOT, test_classes, static_transform=static_transforms, inflation_rate=100)
# Out:
# All known classes: ['Alnus', 'Betula', 'Corylus', 'Acer', 'Pinus', 'Salix', 'Populus tremula', 'Tilia', 'Quercus']
# Train classes: ['Acer', 'Quercus', 'Pinus', 'Corylus', 'Populus tremula']
# Validation classes: ['Tilia', 'Betula']
# Test classes: ['Salix', 'Alnus']
#
# Load Train Dataset
#   0%|          | 0/5 [00:00<?, ?it/s]
# 319 samples in the class Acer
#   0%|          | 0/319 [00:00<?, ?it/s]
# 141 samples in the class Corylus
#   0%|          | 0/141 [00:00<?, ?it/s]
# 67 samples in the class Pinus
#   0%|          | 0/67 [00:00<?, ?it/s]
# 201 samples in the class Populus tremula
#   0%|          | 0/201 [00:00<?, ?it/s]
# 90 samples in the class Quercus
#   0%|          | 0/90 [00:00<?, ?it/s]
# Total samples: 818
#
# Load Validation Dataset
#   0%|          | 0/2 [00:00<?, ?it/s]
# 206 samples in the class Betula
#   0%|          | 0/206 [00:00<?, ?it/s]
# 114 samples in the class Tilia
#   0%|          | 0/114 [00:00<?, ?it/s]
# Total samples: 320
#
# Load Test Dataset
#   0%|          | 0/2 [00:00<?, ?it/s]
# 25 samples in the class Alnus
#   0%|          | 0/25 [00:00<?, ?it/s]
# 227 samples in the class Salix
#   0%|          | 0/227 [00:00<?, ?it/s]
# Total samples: 252

# %%
def plot(imgs, row_title=None, labels=None, **imshow_kwargs):
    if labels != None:
        ax_title = True
    else:
        ax_title = False
    if not isinstance(imgs[0], list):
        # Make a 2d grid even if there's just 1 row
        imgs = [imgs]

    num_rows = len(imgs)
    num_cols = len(imgs[0])
    _, axs = plt.subplots(nrows=num_rows, ncols=num_cols, squeeze=False)
    for row_idx, row in enumerate(imgs):
        for col_idx, img in enumerate(row):
            boxes = None
            masks = None
            if isinstance(img, tuple):
                img, target = img
                if isinstance(target, dict):
                    boxes = target.get("boxes")
                    masks = target.get("masks")
                elif isinstance(target, tv_tensors.BoundingBoxes):
                    boxes = target
                else:
                    raise ValueError(f"Unexpected target type: {type(target)}")
            img = TVF.to_image(img)
            if img.dtype.is_floating_point and img.min() < 0:
                # Poor man's re-normalization for the colors to be OK-ish. This
                # is useful for images coming out of Normalize()
                img -= img.min()
                img /= img.max()

            # print(img.unique())
            img = TVF.to_dtype(img, torch.uint8, scale=True)
            black_pixels = (img != 0).all(dim=0)
            img[:, ~black_pixels] = 255
            if boxes is not None:
                img = draw_bounding_boxes(img, boxes, colors="yellow", width=3)
            if masks is not None:
                img = draw_segmentation_masks(img, masks.to(torch.bool), colors=["green"] * masks.shape[0], alpha=.65)

            ax = axs[row_idx, col_idx]
            ax.imshow(img.permute(1, 2, 0).numpy(), **imshow_kwargs)
            ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])
            if ax_title:
                ax.set_title(labels[col_idx])

    if row_title is not None:
        for row_idx in range(num_rows):
            axs[row_idx, 0].set(ylabel=row_title[row_idx])

    plt.tight_layout()

# %%
training_loader = torch.utils.data.DataLoader(
    dataset_train,
    batch_size= 16,
    shuffle= True,
    num_workers= 6
)
val_loader = torch.utils.data.DataLoader(
    dataset_val, 
    batch_size= 4,
    shuffle= True,
    num_workers= 6
)
test_loader = torch.utils.data.DataLoader(
    dataset_test, 
    batch_size= 1,
    shuffle= True,
    num_workers= 6
)

# %%
for images, label, name in training_loader:
    plot(images[:6], row_title=["images"], labels=name[:6])
    break

# %%
row_count = 0
for anchor, label, name in training_loader:
    plot(anchor[:10])
    row_count +=1
    if row_count >= 10:
        break

# %%
def convert_label_to_similarity(normed_feature: Tensor, label: Tensor) -> Tuple[Tensor, Tensor]:
    similarity_matrix = normed_feature @ normed_feature.transpose(1, 0)
    label_matrix = label.unsqueeze(1) == label.unsqueeze(0)

    positive_matrix = label_matrix.triu(diagonal=1)
    negative_matrix = label_matrix.logical_not().triu(diagonal=1)

    similarity_matrix = similarity_matrix.view(-1)
    positive_matrix = positive_matrix.view(-1)
    negative_matrix = negative_matrix.view(-1)
    return similarity_matrix[positive_matrix], similarity_matrix[negative_matrix]


class CircleLoss(nn.Module):
    def __init__(self, m: float, gamma: float) -> None:
        super(CircleLoss, self).__init__()
        self.m = m
        self.gamma = gamma
        self.soft_plus = nn.Softplus()

    def forward(self, sp: Tensor, sn: Tensor) -> Tensor:
        ap = torch.clamp_min(- sp.detach() + 1 + self.m, min=0.)
        an = torch.clamp_min(sn.detach() + self.m, min=0.)

        delta_p = 1 - self.m
        delta_n = self.m

        logit_p = - ap * (sp - delta_p) * self.gamma
        logit_n = an * (sn - delta_n) * self.gamma

        loss = self.soft_plus(torch.logsumexp(logit_n, dim=0) + torch.logsumexp(logit_p, dim=0))

        return loss

# %%
class EmbeddingModel(nn.Module):
    def __init__(self, backbone, embeddings):
        super().__init__()
        if backbone == "resnet18":
            self.model = models.resnet18(weights='DEFAULT')
            num_features = self.model.fc.in_features
            self.model.fc = nn.Identity()
        elif backbone == "resnet34":
            self.model = models.resnet34(weights='DEFAULT')
            num_features = self.model.fc.in_features
            self.model.fc = nn.Identity()
        elif backbone == "resnet50":
            self.model = models.resnet50(weights='DEFAULT')
            num_features = self.model.fc.in_features
            self.model.fc = nn.Identity()
        elif backbone == "resnet101":
            self.model = models.resnet101(weights='DEFAULT')
            num_features = self.model.fc.in_features
            self.model.fc = nn.Identity()
        elif backbone == "resnet152":
            self.model = models.resnet152(weights='DEFAULT')
            num_features = self.model.fc.in_features
            self.model.fc = nn.Identity()
        elif backbone == "efficientnet_v2":
            self.model = models.efficientnet_v2_s(weights='DEFAULT')
            num_features = self.model.classifier[1].in_features
            self.model.classifier = nn.Identity()
        elif backbone == "inception_v3":
            self.model = models.inception_v3(weights='DEFAULT', aux_logits=False)
            num_features = self.model.fc.in_features
            self.model.fc = nn.Identity()
        elif backbone == "vit":
            self.model = models.vit_b_16(weights='DEFAULT')
            num_features = self.model.heads.head.in_features
            self.model.heads.head = nn.Identity()
        elif backbone == "swin_transformer":
            self.model = models.swin_t(weights='DEFAULT')
            num_features = self.model.head.in_features
            self.model.head = nn.Identity()
        else:
            raise ValueError("Unsupported backbone")

        self.embeddings = nn.Linear(num_features, embeddings)

    def forward(self, x):
        x = self.model(x)
        x = self.embeddings(x)
        x = nn.functional.normalize(x) # L2 normalization to put all values on a sphere
        return x

class PollenEmbedingsModule(L.LightningModule):
    def __init__(self, config):
        super().__init__()
        self.model = EmbeddingModel(config["backbone"], config["embedings_size"])
        
        config["check_val"]=5
        config["optim_lr"]=0.001
        config["optim_betas"]=(0.9, 0.999)
        config["optim_eps"]=1e-08
        config["optim_weight_decay"]=0
        # call this to save (arguments) to the checkpoint
        self.save_hyperparameters(config)

        self.loss_function = CircleLoss(m=0.7, gamma=70)
        self.best_score = 0
        self.best_val_epoch = -1

        self.train_step_outputs = []
        self.val_step_outputs = []
        self.train_losses = []
        self.val_losses = []
        self.to(self.device)

    def forward(self, inputs):
        return self.model(inputs)

    def training_step(self, batch, batch_idx):
        img, label, _ = batch
        pred = self.model(img)
        # print(f"train step: {len(pred)}, {label}")
        loss = self.loss_function(*convert_label_to_similarity(pred, label))
        pred = {"train_loss": loss, "train_number": len(pred)}
        self.train_step_outputs.append(pred)
        return loss

    def on_train_epoch_end(self):
        outputs = self.train_step_outputs
        train_loss, num_items = 0, 0
        for output in outputs:
            train_loss += output["train_loss"].sum().item()
            num_items += output["train_number"]

        mean_train_loss = torch.tensor(train_loss / num_items)
        # print(f"train end: {train_loss}, n={num_items}")
        self.log("train_loss", mean_train_loss)
        self.train_losses.append(mean_train_loss.item())
        self.train_step_outputs.clear()  # free memory

    def validation_step(self, batch, batch_idx):
        img, label, _ = batch
        pred = self.model(img)
        # print(f"val step: {len(pred)}, {label}")
        loss = self.loss_function(*convert_label_to_similarity(pred, label))
        pred = {"val_loss": loss, "val_number": len(pred)}
        self.val_step_outputs.append(pred)
        return loss

    def on_validation_epoch_end(self):
        outputs = self.val_step_outputs
        val_loss, num_items = 0, 0
        for output in outputs:
            val_loss += output["val_loss"].sum().item()
            num_items += output["val_number"]

        # print(f"val end: {val_loss}, n={num_items}")

        mean_val_loss = torch.tensor(val_loss / num_items)
        self.log("val_loss", mean_val_loss)
        self.val_losses.append(mean_val_loss.item())
        self.val_step_outputs.clear()  # free memory

        if mean_val_loss < self.best_score:
            self.best_score = mean_val_loss
            self.best_val_epoch = self.current_epoch

        tensorboard_logs = {
            "val_loss": mean_val_loss
        }

        return {"log": tensorboard_logs}

    def configure_optimizers(self):
        self.optimizer = torch.optim.Adam(self.parameters(),
                                          lr=self.hparams.optim_lr,
                                          betas=self.hparams.optim_betas,
                                          eps=self.hparams.optim_eps,
                                          weight_decay=self.hparams.optim_weight_decay)
        return {
            "optimizer": self.optimizer,
            "lr_scheduler": {
                "scheduler": ReduceLROnPlateau(self.optimizer, factor=0.1, patience=10),
                "frequency": self.hparams.check_val,
                "monitor": "val_loss",
                "interval": "epoch",
            }
        }

    def plot_losses(self):
        plt.figure(figsize=(10, 5))
        plt.plot(self.train_losses, label='Train Loss')
        plt.plot([i * self.hparams.check_val for i in range(len(self.val_losses))], self.val_losses, label='Validation Loss')
        plt.xlabel('Iterations')
        plt.ylabel('Loss')
        plt.title('Training and Validation Losses')
        plt.legend()
        plt.show()

# %%
default_config = {
    "backbone": "resnet50",
    "embedings_size": 128,
}

# %%
# The maximum training epochs
num_epochs = 60

# The directory for saving checkpoints
checkpoint_dir = os.path.join("/tmp", "ray_results")

# %%
def train_func(config):
    model = PollenEmbedingsModule(config)

    trainer = pl.Trainer(
        devices="auto",
        accelerator="auto",
        strategy=RayDDPStrategy(),
        callbacks=[RayTrainReportCallback()],
        plugins=[RayLightningEnvironment()],
        enable_progress_bar=False,
        max_epochs=num_epochs,
    )
    trainer = prepare_trainer(trainer)
    trainer.fit(model, train_dataloaders=training_loader, val_dataloaders=val_loader,)

# %%
search_space = {
    "backbone": tune.grid_search(["resnet50", "resnet34", "resnet18", "resnet101", "resnet152", "efficientnet_v2", "vit", "swin_transformer"]),
    "embedings_size": tune.grid_search([64, 128, 256]),
}

# %%
scaling_config = ScalingConfig(
    num_workers=1,
    use_gpu=True,
    resources_per_worker={"CPU": 20, "GPU": 1}
)

run_config = RunConfig(
    checkpoint_config=CheckpointConfig(
        num_to_keep=1,
        checkpoint_score_attribute="val_loss",
        checkpoint_score_order="min",
    ),
    storage_path=checkpoint_dir,
    name="pollen_tuning",
)

# %%
from ray.train.torch import TorchTrainer

# Define a TorchTrainer without hyper-parameters for Tuner
ray_trainer = TorchTrainer(
    train_func,
    scaling_config=scaling_config,
    run_config=run_config,
)

# %%
def tune_pollen_asha():    
    scheduler = ASHAScheduler(
        max_t=num_epochs, 
        grace_period=30, 
        reduction_factor=2
    )
    
    tuner = Tuner(
        ray_trainer,
        param_space={"train_loop_config": search_space},
        tune_config=tune.TuneConfig(
            metric="val_loss",
            mode="min",
            scheduler=scheduler,
        ),
        run_config=run_config
    )
    return tuner.fit()

# %%
results = tune_pollen_asha()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-17 05:49:09</td></tr>
# <tr><td>Running for: </td><td>10:04:30.48        </td></tr>
# <tr><td>Memory:      </td><td>11.5/125.7 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=24<br>Bracket: Iter 60.000: -0.013290962669998407 | Iter 30.000: -0.007266824599355459<br>Logical resource usage: 21.0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:K80)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name              </th><th>status    </th><th>loc                 </th><th>train_loop_config/ba
# ckbone                 </th><th style="text-align: right;">    train_loop_config/em
# bedings_size</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   val_loss</th><th style="text-align: right;">  epoch</th><th style="text-align: right;">  step</th></tr>
# </thead>
# <tbody>
# <tr><td>TorchTrainer_d671b_00000</td><td>TERMINATED</td><td>10.1.147.147:1715157</td><td>resnet50        </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    60</td><td style="text-align: right;">        1529.54 </td><td style="text-align: right;">0.0573708  </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00001</td><td>TERMINATED</td><td>10.1.147.147:1752767</td><td>resnet34        </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    60</td><td style="text-align: right;">         985.052</td><td style="text-align: right;">0.0194485  </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00002</td><td>TERMINATED</td><td>10.1.147.147:1790230</td><td>resnet18        </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    60</td><td style="text-align: right;">         600.529</td><td style="text-align: right;">9.53403e-05</td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00003</td><td>TERMINATED</td><td>10.1.147.147:1827596</td><td>resnet101       </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    60</td><td style="text-align: right;">        2598.13 </td><td style="text-align: right;">0.0254981  </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00004</td><td>TERMINATED</td><td>10.1.147.147:1865419</td><td>resnet152       </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    60</td><td style="text-align: right;">        3616.32 </td><td style="text-align: right;">0.0517424  </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00005</td><td>TERMINATED</td><td>10.1.147.147:1903379</td><td>efficientnet_v2 </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    30</td><td style="text-align: right;">         914.782</td><td style="text-align: right;">0.258501   </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00006</td><td>TERMINATED</td><td>10.1.147.147:1922450</td><td>vit             </td><td style="text-align: right;"> 64</td><td style="text-align: right;">    30</td><td style="text-align: right;">        2132.98 </td><td style="text-align: right;">0.715549   </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00007</td><td>TERMINATED</td><td>10.1.147.147:1941773</td><td>swin_transformer</td><td style="text-align: right;"> 64</td><td style="text-align: right;">    30</td><td style="text-align: right;">         916.558</td><td style="text-align: right;">0.715551   </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00008</td><td>TERMINATED</td><td>10.1.147.147:1960852</td><td>resnet50        </td><td style="text-align: right;">128</td><td style="text-align: right;">    60</td><td style="text-align: right;">        1535.74 </td><td style="text-align: right;">0.000431998</td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00009</td><td>TERMINATED</td><td>10.1.147.147:1998428</td><td>resnet34        </td><td style="text-align: right;">128</td><td style="text-align: right;">    60</td><td style="text-align: right;">         989.61 </td><td style="text-align: right;">2.52391e-05</td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00010</td><td>TERMINATED</td><td>10.1.147.147:2035891</td><td>resnet18        </td><td style="text-align: right;">128</td><td style="text-align: right;">    60</td><td style="text-align: right;">         601.923</td><td style="text-align: right;">0.0237634  </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00011</td><td>TERMINATED</td><td>10.1.147.147:2073258</td><td>resnet101       </td><td style="text-align: right;">128</td><td style="text-align: right;">    30</td><td style="text-align: right;">        1294.76 </td><td style="text-align: right;">0.00373569 </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00012</td><td>TERMINATED</td><td>10.1.147.147:2092420</td><td>resnet152       </td><td style="text-align: right;">128</td><td style="text-align: right;">    60</td><td style="text-align: right;">        3621.17 </td><td style="text-align: right;">0.00713347 </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00013</td><td>TERMINATED</td><td>10.1.147.147:2130379</td><td>efficientnet_v2 </td><td style="text-align: right;">128</td><td style="text-align: right;">    30</td><td style="text-align: right;">         919.067</td><td style="text-align: right;">0.0722682  </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00014</td><td>TERMINATED</td><td>10.1.147.147:2149460</td><td>vit             </td><td style="text-align: right;">128</td><td style="text-align: right;">    30</td><td style="text-align: right;">        2136.73 </td><td style="text-align: right;">0.715304   </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00015</td><td>TERMINATED</td><td>10.1.147.147:2168787</td><td>swin_transformer</td><td style="text-align: right;">128</td><td style="text-align: right;">    30</td><td style="text-align: right;">         918.75 </td><td style="text-align: right;">0.715553   </td><td style="text-align: right;">     29</td><td style="text-align: right;">  1560</td></tr>
# <tr><td>TorchTrainer_d671b_00016</td><td>TERMINATED</td><td>10.1.147.147:2187867</td><td>resnet50        </td><td style="text-align: right;">256</td><td style="text-align: right;">    60</td><td style="text-align: right;">        1540.57 </td><td style="text-align: right;">0.00174258 </td><td style="text-align: right;">     59</td><td style="text-align: right;">  3120</td></tr>
# <tr><td>TorchTrainer_d671b_00017</td><td>TERMINATED</td><td>10.1.147.147:2225443</td><td>resnet34        </td><td style="text-align: right;">256</td><td style="text-align: right;">    30</td><td style="text-align: right;">         503.72 </td><t
# (TorchTrainer pid=1715157) Started distributed worker processes:
# (TorchTrainer pid=1715157) - (ip=10.1.147.147, pid=1715263) world_rank=0, local_rank=0, node_rank=0
# (RayTrainWorker pid=1715263) Setting up process group for: env:// [rank=0, world_size=1]
# (RayTrainWorker pid=1715263) [W Utils.hpp:133] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function getCvarInt)
# (RayTrainWorker pid=1715263) GPU available: True (cuda), used: True
# (RayTrainWorker pid=1715263) TPU available: False, using: 0 TPU cores
# (RayTrainWorker pid=1715263) IPU available: False, using: 0 IPUs
# (RayTrainWorker pid=1715263) HPU available: False, using: 0 HPUs
# (RayTrainWorker pid=1715263) Missing logger folder: /tmp/ray/session_2024-07-16_19-44-33_871945_1712551/artifacts/2024-07-16_19-44-38/pollen_tuning/working_dirs/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/lightning_logs
# (RayTrainWorker pid=1715263) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (RayTrainWorker pid=1715263) [rank0]:[W Utils.hpp:106] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function getCvarString)
# (RayTrainWorker pid=1715263)
# (RayTrainWorker pid=1715263)   | Name          | Type           | Params
# (RayTrainWorker pid=1715263) -------------------------------------------------
# (RayTrainWorker pid=1715263) 0 | model         | EmbeddingModel | 23.6 M
# (RayTrainWorker pid=1715263) 1 | loss_function | CircleLoss     | 0
# (RayTrainWorker pid=1715263) -------------------------------------------------
# (RayTrainWorker pid=1715263) 23.6 M    Trainable params
# (RayTrainWorker pid=1715263) 0         Non-trainable params
# (RayTrainWorker pid=1715263) 23.6 M    Total params
# (RayTrainWorker pid=1715263) 94.557    Total estimated model params size (MB)
# (RayTrainWorker pid=1715263) /opt/conda/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:492: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# (RayTrainWorker pid=1715263) /opt/conda/lib/python3.11/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (RayTrainWorker pid=1715263)   return F.conv2d(input, weight, bias, self.stride,
# (RayTrainWorker pid=1715263) /opt/conda/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:441: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000000)
# 2024-07-16 19:45:21,537	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) /opt/conda/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:441: It is recommended to use `self.log('train_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# 2024-07-16 19:45:46,671	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000001)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000002)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000003)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000004)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000005)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000006)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000007)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000008)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000009)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000010)
# 2024-07-16 19:49:36,623	WARNING util.py:201 -- The `process_trial_save` operation took 0.505 s, which may be a performance bottleneck.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000011)
# 2024-07-16 19:50:01,793	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000012)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000013)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000014)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000015)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000016)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000017)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000018)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000019)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000020)
# 2024-07-16 19:53:51,262	WARNING util.py:201 -- The `process_trial_save` operation took 0.673 s, which may be a performance bottleneck.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000021)
# 2024-07-16 19:54:16,351	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000022)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000023)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000024)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000025)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000026)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000027)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000028)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000029)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000030)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000031)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000032)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000033)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000034)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000035)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000036)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000037)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000038)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000039)
# 2024-07-16 20:01:53,376	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000040)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000041)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000042)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000043)
# 2024-07-16 20:03:34,793	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000044)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000045)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000046)
# 2024-07-16 20:05:16,536	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000047)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000048)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000049)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000050)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000051)
# 2024-07-16 20:06:58,565	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000052)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000053)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000054)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000055)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000056)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000057)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000058)
# (RayTrainWorker pid=1715263) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000059)
# (TorchTrainer pid=1752767) Started distributed worker processes:
# (TorchTrainer pid=1752767) - (ip=10.1.147.147, pid=1752842) world_rank=0, local_rank=0, node_rank=0
# (RayTrainWorker pid=1752842) Setting up process group for: env:// [rank=0, world_size=1]
# (RayTrainWorker pid=1752842) [W Utils.hpp:133] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function getCvarInt)
# (RayTrainWorker pid=1752842) GPU available: True (cuda), used: True
# (RayTrainWorker pid=1752842) TPU available: False, using: 0 TPU cores
# (RayTrainWorker pid=1752842) IPU available: False, using: 0 IPUs
# (RayTrainWorker pid=1752842) HPU available: False, using: 0 HPUs
# (RayTrainWorker pid=1752842) Missing logger folder: /tmp/ray/session_2024-07-16_19-44-33_871945_1712551/artifacts/2024-07-16_19-44-38/pollen_tuning/working_dirs/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/lightning_logs
# (RayTrainWorker pid=1752842) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (RayTrainWorker pid=1752842) [rank0]:[W Utils.hpp:106] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function getCvarString)
# (RayTrainWorker pid=1752842)
# (RayTrainWorker pid=1752842)   | Name          | Type           | Params
# (RayTrainWorker pid=1752842) -------------------------------------------------
# (RayTrainWorker pid=1752842) 0 | model         | EmbeddingModel | 21.3 M
# (RayTrainWorker pid=1752842) 1 | loss_function | CircleLoss     | 0
# (RayTrainWorker pid=1752842) -------------------------------------------------
# (RayTrainWorker pid=1752842) 21.3 M    Trainable params
# (RayTrainWorker pid=1752842) 0         Non-trainable params
# (RayTrainWorker pid=1752842) 21.3 M    Total params
# (RayTrainWorker pid=1752842) 85.270    Total estimated model params size (MB)
# (RayTrainWorker pid=1752842) /opt/conda/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:492: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# (RayTrainWorker pid=1752842) /opt/conda/lib/python3.11/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
# (RayTrainWorker pid=1752842)   return F.conv2d(input, weight, bias, self.stride,
# (RayTrainWorker pid=1752842) /opt/conda/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:441: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# 2024-07-16 20:10:55,745	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000000)
# (RayTrainWorker pid=1752842) /opt/conda/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:441: It is recommended to use `self.log('train_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000001)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000002)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000003)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000004)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000005)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000006)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000007)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000008)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000009)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000010)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000011)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000012)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000013)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000014)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000015)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000016)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000017)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000018)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000019)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000020)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000021)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000022)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000023)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000024)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000025)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000026)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000027)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000028)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000029)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000030)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000031)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000032)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000033)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000034)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000035)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000036)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000037)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000038)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000039)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000040)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000041)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000042)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000043)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000044)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000045)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000046)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000047)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000048)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000049)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000050)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000051)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000052)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000053)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000054)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000055)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000056)
# (RayTrainWorker pid=1752842) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000057)
# ...
# 2024-07-17 05:40:56,880	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000014)
# 2024-07-17 05:41:28,066	WARNING util.py:201 -- The `process_trial_save` operation took 0.624 s, which may be a performance bottleneck.
# 2024-07-17 05:41:28,112	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# 2024-07-17 05:41:58,440	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000015)
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000016)
# 2024-07-17 05:42:28,911	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000017)
# 2024-07-17 05:43:00,159	WARNING util.py:201 -- The `process_trial_save` operation took 0.672 s, which may be a performance bottleneck.
# 2024-07-17 05:43:00,262	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000018)
# 2024-07-17 05:43:30,579	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# 2024-07-17 05:44:01,165	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000019)
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000020)
# 2024-07-17 05:44:32,594	WARNING util.py:201 -- The `process_trial_save` operation took 0.957 s, which may be a performance bottleneck.
# 2024-07-17 05:44:32,601	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# 2024-07-17 05:45:02,817	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000021)
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000022)
# 2024-07-17 05:45:34,263	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000023)
# 2024-07-17 05:46:05,330	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000024)
# 2024-07-17 05:46:36,109	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000025)
# 2024-07-17 05:47:06,592	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000026)
# 2024-07-17 05:47:37,024	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000027)
# 2024-07-17 05:48:07,930	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000028)
# 2024-07-17 05:48:38,766	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (RayTrainWorker pid=2377243) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000029)
# 2024-07-17 05:49:09,229	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# 2024-07-17 05:49:09,304	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/tmp/ray_results/pollen_tuning' in 0.0736s.
# 2024-07-17 05:49:09,319	INFO tune.py:1041 -- Total run time: 36270.52 seconds (36270.41 seconds for the tuning loop).

# %%
results.get_best_result(metric="val_loss", mode="min")
# Out:
# Result(
#   metrics={'val_loss': 1.0105835826834664e-05, 'train_loss': 0.00014480555546469986, 'epoch': 59, 'step': 3120},
#   path='/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00018_18_backbone=resnet18,embedings_size=256_2024-07-16_19-44-38',
#   filesystem='local',
#   checkpoint=Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00018_18_backbone=resnet18,embedings_size=256_2024-07-16_19-44-38/checkpoint_000059)
# )

# %%
results_dir = "/tmp/ray_results/pollen_tuning"

analysis = ExperimentAnalysis(results_dir)
best_trial = analysis.get_best_trial(metric="val_loss", mode="min", scope="all")

best_checkpoint = analysis.get_best_checkpoint(best_trial, metric="val_loss", mode="min")

print("The best result:\nName:", best_trial.trial_id)
print("Config:", best_trial.config)
print("Metrics:", best_trial.metric_analysis["val_loss"])
# Out:
# The best result:
# Name: d671b_00016
# Config: {'train_loop_config': {'backbone': 'resnet50', 'embedings_size': 256}}
# Metrics: {'max': 0.050993505865335464, 'min': 2.1851718212673177e-09, 'avg': 0.005740408066211883, 'last': 0.0017425849800929427, 'last-5-avg': 0.0026810219565959414, 'last-10-avg': 0.0035282777780594188}

# %%
trials = analysis.trials

for i, trial in enumerate(trials):
    try:
        best_checkpoint = analysis.get_best_checkpoint(trial, metric="val_loss", mode="min")
        print(f"Trial {i+1}:")
        print(f"  Trial ID: {trial.trial_id}")
        print(f"  Config: {trial.config}")
        print(f"  Metric: {trial.metric_analysis['val_loss']['min']}")
        print(f"  Checkpoint: {best_checkpoint}")
        print("\n")
    except:
        pass
# Out:
# Trial 1:
#   Trial ID: d671b_00000
#   Config: {'train_loop_config': {'backbone': 'resnet50', 'embedings_size': 64}}
#   Metric: 2.1995207077907253e-07
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00000_0_backbone=resnet50,embedings_size=64_2024-07-16_19-44-38/checkpoint_000046)
#
#
# Trial 2:
#   Trial ID: d671b_00007
#   Config: {'train_loop_config': {'backbone': 'swin_transformer', 'embedings_size': 64}}
#   Metric: 0.6391431093215942
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00007_7_backbone=swin_transformer,embedings_size=64_2024-07-16_19-44-38/checkpoint_000004)
#
#
# Trial 3:
#   Trial ID: d671b_00014
#   Config: {'train_loop_config': {'backbone': 'vit', 'embedings_size': 128}}
#   Metric: 0.015090164728462696
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00014_14_backbone=vit,embedings_size=128_2024-07-16_19-44-38/checkpoint_000005)
#
#
# Trial 4:
#   Trial ID: d671b_00020
#   Config: {'train_loop_config': {'backbone': 'resnet152', 'embedings_size': 256}}
#   Metric: 3.4011643492704025e-06
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00020_20_backbone=resnet152,embedings_size=256_2024-07-16_19-44-38/checkpoint_000017)
#
#
# Trial 5:
#   Trial ID: d671b_00015
#   Config: {'train_loop_config': {'backbone': 'swin_transformer', 'embedings_size': 128}}
#   Metric: 0.5633039474487305
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00015_15_backbone=swin_transformer,embedings_size=128_2024-07-16_19-44-38/checkpoint_000001)
#
#
# Trial 6:
#   Trial ID: d671b_00009
#   Config: {'train_loop_config': {'backbone': 'resnet34', 'embedings_size': 128}}
#   Metric: 1.0424830634292448e-06
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00009_9_backbone=resnet34,embedings_size=128_2024-07-16_19-44-38/checkpoint_000046)
#
#
# Trial 7:
#   Trial ID: d671b_00005
#   Config: {'train_loop_config': {'backbone': 'efficientnet_v2', 'embedings_size': 64}}
#   Metric: 0.020743384957313538
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00005_5_backbone=efficientnet_v2,embedings_size=64_2024-07-16_19-44-38/checkpoint_000003)
#
#
# Trial 8:
#   Trial ID: d671b_00017
#   Config: {'train_loop_config': {'backbone': 'resnet34', 'embedings_size': 256}}
#   Metric: 0.00021453559747897089
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00017_17_backbone=resnet34,embedings_size=256_2024-07-16_19-44-38/checkpoint_000018)
#
#
# Trial 9:
#   Trial ID: d671b_00018
#   Config: {'train_loop_config': {'backbone': 'resnet18', 'embedings_size': 256}}
#   Metric: 6.586179157608285e-09
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00018_18_backbone=resnet18,embedings_size=256_2024-07-16_19-44-38/checkpoint_000033)
#
#
# Trial 10:
#   Trial ID: d671b_00021
#   Config: {'train_loop_config': {'backbone': 'efficientnet_v2', 'embedings_size': 256}}
#   Metric: 3.4095039609383093e-06
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00021_21_backbone=efficientnet_v2,embedings_size=256_2024-07-16_19-44-38/checkpoint_000045)
#
#
# Trial 11:
#   Trial ID: d671b_00003
#   Config: {'train_loop_config': {'backbone': 'resnet101', 'embedings_size': 64}}
#   Metric: 0.000177218287717551
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00003_3_backbone=resnet101,embedings_size=64_2024-07-16_19-44-38/checkpoint_000016)
#
#
# Trial 12:
#   Trial ID: d671b_00006
#   Config: {'train_loop_config': {'backbone': 'vit', 'embedings_size': 64}}
#   Metric: 0.6496660709381104
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00006_6_backbone=vit,embedings_size=64_2024-07-16_19-44-38/checkpoint_000022)
#
#
# Trial 13:
#   Trial ID: d671b_00008
#   Config: {'train_loop_config': {'backbone': 'resnet50', 'embedings_size': 128}}
#   Metric: 4.602816794374576e-09
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00008_8_backbone=resnet50,embedings_size=128_2024-07-16_19-44-38/checkpoint_000006)
#
#
# Trial 14:
#   Trial ID: d671b_00013
#   Config: {'train_loop_config': {'backbone': 'efficientnet_v2', 'embedings_size': 128}}
#   Metric: 0.04932231828570366
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00013_13_backbone=efficientnet_v2,embedings_size=128_2024-07-16_19-44-38/checkpoint_000028)
#
#
# Trial 15:
#   Trial ID: d671b_00010
#   Config: {'train_loop_config': {'backbone': 'resnet18', 'embedings_size': 128}}
#   Metric: 5.928842483626795e-07
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00010_10_backbone=resnet18,embedings_size=128_2024-07-16_19-44-38/checkpoint_000053)
#
#
# Trial 16:
#   Trial ID: d671b_00016
#   Config: {'train_loop_config': {'backbone': 'resnet50', 'embedings_size': 256}}
#   Metric: 2.1851718212673177e-09
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00016_16_backbone=resnet50,embedings_size=256_2024-07-16_19-44-38/checkpoint_000035)
#
#
# Trial 17:
#   Trial ID: d671b_00023
#   Config: {'train_loop_config': {'backbone': 'swin_transformer', 'embedings_size': 256}}
#   Metric: 0.2704611122608185
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00023_23_backbone=swin_transformer,embedings_size=256_2024-07-16_19-44-38/checkpoint_000020)
#
#
# Trial 18:
#   Trial ID: d671b_00004
#   Config: {'train_loop_config': {'backbone': 'resnet152', 'embedings_size': 64}}
#   Metric: 1.2014122603432043e-06
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00004_4_backbone=resnet152,embedings_size=64_2024-07-16_19-44-38/checkpoint_000050)
#
#
# Trial 19:
#   Trial ID: d671b_00011
#   Config: {'train_loop_config': {'backbone': 'resnet101', 'embedings_size': 128}}
#   Metric: 6.49443973088637e-05
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00011_11_backbone=resnet101,embedings_size=128_2024-07-16_19-44-38/checkpoint_000017)
#
#
# Trial 20:
#   Trial ID: d671b_00012
#   Config: {'train_loop_config': {'backbone': 'resnet152', 'embedings_size': 128}}
#   Metric: 2.5493505972917774e-07
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00012_12_backbone=resnet152,embedings_size=128_2024-07-16_19-44-38/checkpoint_000038)
#
#
# Trial 21:
#   Trial ID: d671b_00001
#   Config: {'train_loop_config': {'backbone': 'resnet34', 'embedings_size': 64}}
#   Metric: 4.86454700876493e-06
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00001_1_backbone=resnet34,embedings_size=64_2024-07-16_19-44-38/checkpoint_000017)
#
#
# Trial 22:
#   Trial ID: d671b_00019
#   Config: {'train_loop_config': {'backbone': 'resnet101', 'embedings_size': 256}}
#   Metric: 6.897320758980641e-07
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00019_19_backbone=resnet101,embedings_size=256_2024-07-16_19-44-38/checkpoint_000011)
#
#
# Trial 23:
#   Trial ID: d671b_00022
#   Config: {'train_loop_config': {'backbone': 'vit', 'embedings_size': 256}}
#   Metric: 0.4836901128292084
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00022_22_backbone=vit,embedings_size=256_2024-07-16_19-44-38/checkpoint_000015)
#
#
# Trial 24:
#   Trial ID: d671b_00002
#   Config: {'train_loop_config': {'backbone': 'resnet18', 'embedings_size': 64}}
#   Metric: 2.0093027330858604e-07
#   Checkpoint: Checkpoint(filesystem=local, path=/tmp/ray_results/pollen_tuning/TorchTrainer_d671b_00002_2_backbone=resnet18,embedings_size=64_2024-07-16_19-44-38/checkpoint_000016)
